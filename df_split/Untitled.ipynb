# %%
import numpy as np
import pandas as pd
import random

# %%
data = random.random(1000)

# %%
percentage = 0.2
k = int(len(data) * percentage)
random.sample(data.tolist(), k)
# Out:
# [0.41574778457606343,
#  0.23401828459906493,
#  0.8554975032414168,
#  0.3416439696535196,
#  0.27721914201736464,
#  0.08813324220667418,
#  0.906184723342182,
#  0.33220385404194264,
#  0.47219247719838575,
#  0.33251638623507307,
#  0.35300323429962555,
#  0.2065415510778652,
#  0.5540788040817456,
#  0.16548386664847803,
#  0.42683372989113433,
#  0.43801706524028283,
#  0.900085505447483,
#  0.03579426980564737,
#  0.1252349384558522,
#  0.8041910777883287,
#  0.0649771074463934,
#  0.28631222203192497,
#  0.4442925633882938,
#  0.4311554046579583,
#  0.6772259906863587,
#  0.4814680621117068,
#  0.5102826626048531,
#  0.4352632554069692,
#  0.9750106050072554,
#  0.15746728914097574,
#  0.03175558432306347,
#  0.6701682192070455,
#  0.902828793743299,
#  0.2215121833106546,
#  0.7794435673813706,
#  0.9839379734170742,
#  0.3083679591554255,
#  0.4506920077424822,
#  0.8121690032540949,
#  0.7264765834631071,
#  0.9002512306144808,
#  0.4788089548000195,
# ...

# %%
# Out:
# 200.0
